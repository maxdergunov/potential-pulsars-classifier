# %%
from itertools import product
from datetime import datetime

import pandas as pd

from model import choose_dataset, train_model, add_new_row

import warnings
warnings.filterwarnings('ignore')

# %%
tune_list = [True, False]
scaling_list = [True, False]
pca_list = [True, False]
sampling_list = ['rus', 'nm-3', 'cnn', 'ros', 'smote', 'adasyn']

abc_results = pd.DataFrame(columns=['Algorithm', 'Non-pulsar precision', 'Non-pulsar recall', 'Non-pulsar F1', 'Pulsar precision', 'Pulsar recall', 'Pulsar F1', 'Weighted precision', 'Weighted recall', 'Weighted F1', 'Matthews corrcoefficient', "Cohen's Kappa", 'Parameters', 'PCA', 'Tuning', 'Scaling', 'Sampling'])

n = 0

print('Start time at', datetime.now().strftime("%H:%M:%S"))

for tuning, scaling, pca, sampling in product(tune_list, scaling_list, pca_list, sampling_list):
    n += 1
    print('Starting Algorithm - AdaBoost, Autotuning - {}, Scaling - {}, Pca - {}, Oversampling - {} ({} out of {})'.format(
        tuning, scaling, pca, sampling, n, len(list(product(tune_list, scaling_list, pca_list, sampling_list)))))
    

    algorithm, preds, y_test = train_model(algo='abc', pca=pca, tuning=tuning, scaling=scaling, n_splits=5, sampling=sampling, n_jobs=7, scoring='cohen', verbose=0)     
    row = add_new_row(algorithm, preds, y_test)
    row['Algorithm'] = 'AdaBoost'
    row['PCA'] = pca
    row['Tuning'] = tuning
    row['Scaling'] = scaling
    row['Sampling'] = sampling
    abc_results.loc[len(abc_results)] = row
    print('Done at', datetime.now().strftime("%H:%M:%S"), '\n')
    abc_results.to_csv('./results/abc_results.csv', index=False)
# Out:
# Start time at 11:45:21
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - True, Pca - True, Oversampling - rus (1 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_rus.csv
# Loaded ./data/y_train_scaled_pca_rus.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:47:13
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - True, Pca - True, Oversampling - nm-3 (2 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_nm-3.csv
# Loaded ./data/y_train_scaled_pca_nm-3.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:48:55
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - True, Pca - True, Oversampling - cnn (3 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_cnn.csv
# Loaded ./data/y_train_scaled_pca_cnn.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:50:34
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - True, Pca - True, Oversampling - ros (4 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_ros.csv
# Loaded ./data/y_train_scaled_pca_ros.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:55:16
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - True, Pca - True, Oversampling - smote (5 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_smote.csv
# Loaded ./data/y_train_scaled_pca_smote.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:00:01
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - True, Pca - True, Oversampling - adasyn (6 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_adasyn.csv
# Loaded ./data/y_train_scaled_pca_adasyn.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:04:29
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - True, Pca - False, Oversampling - rus (7 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_rus.csv
# Loaded ./data/y_train_scaled_rus.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:07:22
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - True, Pca - False, Oversampling - nm-3 (8 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_nm-3.csv
# Loaded ./data/y_train_scaled_nm-3.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:09:37
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - True, Pca - False, Oversampling - cnn (9 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_cnn.csv
# Loaded ./data/y_train_scaled_cnn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:12:02
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - True, Pca - False, Oversampling - ros (10 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_ros.csv
# Loaded ./data/y_train_scaled_ros.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:22:54
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - True, Pca - False, Oversampling - smote (11 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_smote.csv
# Loaded ./data/y_train_scaled_smote.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:33:53
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - True, Pca - False, Oversampling - adasyn (12 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_adasyn.csv
# Loaded ./data/y_train_scaled_adasyn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:44:13
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - False, Pca - True, Oversampling - rus (13 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_rus.csv
# Loaded ./data/y_train_pca_rus.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:46:08
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - False, Pca - True, Oversampling - nm-3 (14 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_nm-3.csv
# Loaded ./data/y_train_pca_nm-3.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:47:34
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - False, Pca - True, Oversampling - cnn (15 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_cnn.csv
# Loaded ./data/y_train_pca_cnn.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:49:25
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - False, Pca - True, Oversampling - ros (16 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_ros.csv
# Loaded ./data/y_train_pca_ros.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:53:48
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - False, Pca - True, Oversampling - smote (17 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_smote.csv
# Loaded ./data/y_train_pca_smote.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:57:54
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - False, Pca - True, Oversampling - adasyn (18 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_adasyn.csv
# Loaded ./data/y_train_pca_adasyn.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:02:12
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - False, Pca - False, Oversampling - rus (19 out of 48)
# Training begins...
# Loaded ./data/X_train_rus.csv
# Loaded ./data/y_train_rus.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:04:34
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - False, Pca - False, Oversampling - nm-3 (20 out of 48)
# Training begins...
# Loaded ./data/X_train_nm-3.csv
# Loaded ./data/y_train_nm-3.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:06:41
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - False, Pca - False, Oversampling - cnn (21 out of 48)
# Training begins...
# Loaded ./data/X_train_cnn.csv
# Loaded ./data/y_train_cnn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:09:01
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - False, Pca - False, Oversampling - ros (22 out of 48)
# Training begins...
# Loaded ./data/X_train_ros.csv
# Loaded ./data/y_train_ros.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:18:59
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - False, Pca - False, Oversampling - smote (23 out of 48)
# Training begins...
# Loaded ./data/X_train_smote.csv
# Loaded ./data/y_train_smote.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:29:10
#
# Starting Algorithm - AdaBoost, Autotuning - True, Scaling - False, Pca - False, Oversampling - adasyn (24 out of 48)
# Training begins...
# Loaded ./data/X_train_adasyn.csv
# Loaded ./data/y_train_adasyn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:39:42
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - True, Pca - True, Oversampling - rus (25 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_rus.csv
# Loaded ./data/y_train_scaled_pca_rus.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:42
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - True, Pca - True, Oversampling - nm-3 (26 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_nm-3.csv
# Loaded ./data/y_train_scaled_pca_nm-3.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:42
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - True, Pca - True, Oversampling - cnn (27 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_cnn.csv
# Loaded ./data/y_train_scaled_pca_cnn.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:42
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - True, Pca - True, Oversampling - ros (28 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_ros.csv
# Loaded ./data/y_train_scaled_pca_ros.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:43
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - True, Pca - True, Oversampling - smote (29 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_smote.csv
# Loaded ./data/y_train_scaled_pca_smote.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:43
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - True, Pca - True, Oversampling - adasyn (30 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_adasyn.csv
# Loaded ./data/y_train_scaled_pca_adasyn.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:44
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - True, Pca - False, Oversampling - rus (31 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_rus.csv
# Loaded ./data/y_train_scaled_rus.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:44
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - True, Pca - False, Oversampling - nm-3 (32 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_nm-3.csv
# Loaded ./data/y_train_scaled_nm-3.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:44
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - True, Pca - False, Oversampling - cnn (33 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_cnn.csv
# Loaded ./data/y_train_scaled_cnn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:45
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - True, Pca - False, Oversampling - ros (34 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_ros.csv
# Loaded ./data/y_train_scaled_ros.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:46
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - True, Pca - False, Oversampling - smote (35 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_smote.csv
# Loaded ./data/y_train_scaled_smote.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:46
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - True, Pca - False, Oversampling - adasyn (36 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_adasyn.csv
# Loaded ./data/y_train_scaled_adasyn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:47
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - False, Pca - True, Oversampling - rus (37 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_rus.csv
# Loaded ./data/y_train_pca_rus.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:48
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - False, Pca - True, Oversampling - nm-3 (38 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_nm-3.csv
# Loaded ./data/y_train_pca_nm-3.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:48
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - False, Pca - True, Oversampling - cnn (39 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_cnn.csv
# Loaded ./data/y_train_pca_cnn.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:48
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - False, Pca - True, Oversampling - ros (40 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_ros.csv
# Loaded ./data/y_train_pca_ros.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:48
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - False, Pca - True, Oversampling - smote (41 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_smote.csv
# Loaded ./data/y_train_pca_smote.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:49
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - False, Pca - True, Oversampling - adasyn (42 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_adasyn.csv
# Loaded ./data/y_train_pca_adasyn.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:49
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - False, Pca - False, Oversampling - rus (43 out of 48)
# Training begins...
# Loaded ./data/X_train_rus.csv
# Loaded ./data/y_train_rus.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:50
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - False, Pca - False, Oversampling - nm-3 (44 out of 48)
# Training begins...
# Loaded ./data/X_train_nm-3.csv
# Loaded ./data/y_train_nm-3.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:50
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - False, Pca - False, Oversampling - cnn (45 out of 48)
# Training begins...
# Loaded ./data/X_train_cnn.csv
# Loaded ./data/y_train_cnn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:50
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - False, Pca - False, Oversampling - ros (46 out of 48)
# Training begins...
# Loaded ./data/X_train_ros.csv
# Loaded ./data/y_train_ros.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:51
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - False, Pca - False, Oversampling - smote (47 out of 48)
# Training begins...
# Loaded ./data/X_train_smote.csv
# Loaded ./data/y_train_smote.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:52
#
# Starting Algorithm - AdaBoost, Autotuning - False, Scaling - False, Pca - False, Oversampling - adasyn (48 out of 48)
# Training begins...
# Loaded ./data/X_train_adasyn.csv
# Loaded ./data/y_train_adasyn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 13:39:53

# %%
abc_results.sort_values(by="Cohen's Kappa", ascending=False).reset_index(drop=True)
# Out:
#    Algorithm  Non-pulsar precision  Non-pulsar recall  Non-pulsar F1  \
# 0   AdaBoost              0.985492           0.992591       0.989029
# 1   AdaBoost              0.985282           0.991974       0.988617
# 2   AdaBoost              0.985282           0.991974       0.988617
# 3   AdaBoost              0.985872           0.990945       0.988402
# 4   AdaBoost              0.985069           0.991150       0.988100
# 5   AdaBoost              0.987443           0.987240       0.987342
# 6   AdaBoost              0.984260           0.990945       0.987591
# 7   AdaBoost              0.985445           0.989298       0.987368
# 8   AdaBoost              0.986434           0.987652       0.987042
# 9   AdaBoost              0.984449           0.990121       0.987277
# 10  AdaBoost              0.984449           0.990121       0.987277
# 11  AdaBoost              0.985035           0.988887       0.986957
# 12  AdaBoost              0.988430           0.984565       0.986493
# 13  AdaBoost              0.987214           0.985182       0.986197
# 14  AdaBoost              0.987010           0.985182       0.986095
# 15  AdaBoost              0.985394           0.985800       0.985597
# 16  AdaBoost              0.979472           0.991768       0.985581
# 17  AdaBoost              0.979472           0.991768       0.985581
# 18  AdaBoost              0.980037           0.990121       0.985053
# 19  AdaBoost              0.978676           0.991768       0.985178
# 20  AdaBoost              0.983738           0.983536       0.983637
# 21  AdaBoost              0.982150           0.985182       0.983664
# 22  AdaBoost              0.989956           0.973657       0.981739
# 23  AdaBoost              0.980742           0.985182       0.982957
# 24  AdaBoost              0.983096           0.981478       0.982286
# 25  AdaBoost              0.980521           0.984153       0.982334
# 26  AdaBoost              0.981097           0.982712       0.981904
# 27  AdaBoost              0.991762           0.966248       0.978839
# 28  AdaBoost              0.986042           0.974069       0.980019
# 29  AdaBoost              0.982184           0.975715       0.978939
# 30  AdaBoost              0.982759           0.973657       0.978187
# 31  AdaBoost              0.979975           0.976950       0.978460
# 32  AdaBoost              0.981743           0.973863       0.977787
# 33  AdaBoost              0.981516           0.972628       0.977052
# 34  AdaBoost              0.987128           0.962750       0.974786
# 35  AdaBoost              0.991245           0.955341       0.972962
# 36  AdaBoost              0.991245           0.955341       0.972962
# 37  AdaBoost              0.982456           0.968100       0.975225
# 38  AdaBoost              0.986229           0.958016       0.971918
# 39  AdaBoost              0.983786           0.961515       0.972523
# 40  AdaBoost              0.981956           0.963161       0.972468
# 41  AdaBoost              0.980474           0.961103       0.970692
# 42  AdaBoost              0.985196           0.945050       0.964706
# 43  AdaBoost              0.982067           0.946697       0.964057
# 44  AdaBoost              0.979744           0.945668       0.962404
# 45  AdaBoost              0.990097           0.905330       0.945818
# 46  AdaBoost              0.983803           0.912533       0.946829
# 47  AdaBoost              0.989777           0.896687       0.940935
#
#     Pulsar precision  Pulsar recall  Pulsar F1  Weighted precision  \
# 0           0.924211       0.860784   0.891371            0.979671
# 1           0.918239       0.858824   0.887538            0.978914
# 23         0.969082     0.968776                     0.817          0.817
# 24         0.967964     0.968076                     0.815          0.815
# 25         0.967964     0.967706                     0.811          0.811
# 26         0.967219     0.967103                     0.808          0.808
# 27         0.962190     0.964008                     0.808          0.802
# 28         0.964053     0.964926                     0.803          0.801
# 29         0.962004     0.962519                     0.785          0.785
# 30         0.960700     0.961439                     0.781          0.780
# 31         0.961073     0.961325                     0.777          0.777
# 32         0.959955     0.960612                     0.775          0.775
# 33         0.958652     0.959412                     0.769          0.768
# 34         0.954926     0.957017                     0.768          0.763
# 35         0.951946     0.955039                     0.768          0.758
# 36         0.951946     0.955039                     0.768          0.758
# 37         0.955485     0.956770                     0.758          0.756
# 38         0.949898     0.952538                     0.747          0.740
# 39         0.950829     0.952941                     0.744          0.739
# 40         0.950643     0.952466                     0.738          0.735
# 41         0.947476     0.949473                     0.722          0.718
# 42         0.937419     0.941854                     0.702          0.690
# 43         0.936115     0.940207                     0.687          0.678
# 44         0.933135     0.937295                     0.670          0.661
# 45         0.906128     0.917626                     0.636          0.600
# 46         0.907245     0.917401                     0.614          0.588
# 47         0.898119     0.911367                     0.617          0.577
#
#                                            Parameters    PCA Tuning Scaling  \
# 0   {'algorithm': 'SAMME.R', 'base_estimator': Non...  False   True    True
# 1   {'algorithm': 'SAMME.R', 'base_estimator': Non...  False   True   False
# 2   {'algorithm': 'SAMME.R', 'base_estimator': Non...  False   True    True
# 3   {'algorithm': 'SAMME.R', 'base_estimator': Non...  False   True   False
# 4   {'algorithm': 'SAMME.R', 'base_estimator': Non...  False  False    True
# 5   {'algorithm': 'SAMME.R', 'base_estimator': Non...  False   True    True
# 6   {'algorithm': 'SAMME.R', 'base_estimator': Non...  False  False   False
# 7   {'algorithm': 'SAMME', 'base_estimator': None,...  False   True    True
# 8   {'algorithm': 'SAMME.R', 'base_estimator': Non...  False  False    True
# 9   {'algorithm': 'SAMME.R', 'base_estimator': Non...  False  False    True
# 10  {'algorithm': 'SAMME.R', 'base_estimator': Non...  False  False   False
# 11  {'algorithm': 'SAMME.R', 'base_estimator': Non...  False  False    True
# 12  {'algorithm': 'SAMME.R', 'base_estimator': Non...  False   True   False
# 13  {'algorithm': 'SAMME.R', 'base_estimator': Non...  False  False   False
# 14  {'algorithm': 'SAMME.R', 'base_estimator': Non...  False   True   False
# 15  {'algorithm': 'SAMME.R', 'base_estimator': Non...  False  False   False
# 16  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True   True    True
# 17  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True  False    True
# 18  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True   True    True
# 19  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True  False    True
# 20  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True   True    True
# 21  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True   True    True
# 22  {'algorithm': 'SAMME', 'base_estimator': None,...  False   True    True
# 23  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True   True    True
# 24  {'algorithm': 'SAMME.R', 'base_estimator': Non...  False  False    True
# 25  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True  False    True
# 26  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True  False    True
# 27  {'algorithm': 'SAMME.R', 'base_estimator': Non...  False   True   False
# 28  {'algorithm': 'SAMME.R', 'base_estimator': Non...  False   True   False
# 29  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True   True   False
# 30  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True  False    True
# 31  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True   True   False
# 32  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True   True   False
# 33  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True  False   False
# 34  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True   True    True
# 35  {'algorithm': 'SAMME.R', 'base_estimator': Non...  False  False    True
# 36  {'algorithm': 'SAMME.R', 'base_estimator': Non...  False  False   False
# 37  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True  False   False
# 38  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True  False    True
# 39  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True  False   False
# 40  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True   True   False
# 41  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True   True   False
# 42  {'algorithm': 'SAMME.R', 'base_estimator': Non...  False  False   False
# 43  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True  False   False
# 44  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True  False   False
# 45  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True   True   False
# 46  {'algorithm': 'SAMME.R', 'base_estimator': Non...  False   True    True
# 47  {'algorithm': 'SAMME.R', 'base_estimator': Non...   True  False   False
#
#    Sampling
# 0     smote
# 1       ros
# 2       ros
# 3     smote
# 4     smote
# 5    adasyn
# 6     smote
# 7       cnn
# 8    adasyn
# 9       ros
# 10      ros
# 11      cnn
# 12   adasyn
# 13   adasyn
# 14      cnn
# 15      cnn
# 16      ros
# 17    smote
# 18    smote
# 19      ros
# 20   adasyn
# 21      cnn
# 22      rus
# 23     nm-3
# 24     nm-3
# 25      cnn
# 26   adasyn
# 27      rus
# 28     nm-3
# 29    smote
# 30     nm-3
# 31      ros
# 32   adasyn
# 33      ros
# 34      rus
# 35      rus
# 36      rus
# 37    smote
# 38      rus
# 39   adasyn
# 40      cnn
# 41     nm-3
# 42     nm-3
# 43     nm-3
# 44      cnn
# 45      rus
# 46     nm-3
# 47      rus
