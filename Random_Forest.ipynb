# %%
from itertools import product
from datetime import datetime

import pandas as pd

from model import choose_dataset, train_model, add_new_row

import warnings
warnings.filterwarnings('ignore')

# %%
tune_list = [True, False]
scaling_list = [True, False]
pca_list = [False, False]
sampling_list = ['rus', 'nm-3', 'cnn', 'ros', 'smote', 'adasyn']

rf_results = pd.DataFrame(columns=['Algorithm', 'Non-pulsar precision', 'Non-pulsar recall', 'Non-pulsar F1', 'Pulsar precision', 'Pulsar recall', 'Pulsar F1', 'Weighted precision', 'Weighted recall', 'Weighted F1', 'Matthews corrcoefficient', "Cohen's Kappa", 'Parameters', 'PCA', 'Tuning', 'Scaling', 'Sampling'])

n = 0

print('Start time at', datetime.now().strftime("%H:%M:%S"))

for tuning, scaling, pca, sampling in product(tune_list, scaling_list, pca_list, sampling_list):
    n += 1
    print('Starting Algorithm - Random Forest, Autotuning - {}, Scaling - {}, Pca - {}, Oversampling - {} ({} out of {})'.format(
        tuning, scaling, pca, sampling, n, len(list(product(tune_list, scaling_list, pca_list, sampling_list)))))
    

    algorithm, preds, y_test = train_model(algo='rf', pca=pca, tuning=tuning, scaling=scaling, n_splits=5, sampling=sampling, n_jobs=7, scoring='cohen', verbose=0)     
    row = add_new_row(algorithm, preds, y_test)
    row['Algorithm'] = 'Random Forest'
    row['PCA'] = pca
    row['Tuning'] = tuning
    row['Scaling'] = scaling
    row['Sampling'] = sampling
    rf_results.loc[len(rf_results)] = row
    print('Done at', datetime.now().strftime("%H:%M:%S"), '\n')
    rf_results.to_csv('./results/rf_results.csv', index=False)
# Out:
# Start time at 11:32:26
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - True, Pca - False, Oversampling - rus (1 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_rus.csv
# Loaded ./data/y_train_scaled_rus.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:32:56
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - True, Pca - False, Oversampling - nm-3 (2 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_nm-3.csv
# Loaded ./data/y_train_scaled_nm-3.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:33:19
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - True, Pca - False, Oversampling - cnn (3 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_cnn.csv
# Loaded ./data/y_train_scaled_cnn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:33:46
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - True, Pca - False, Oversampling - ros (4 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_ros.csv
# Loaded ./data/y_train_scaled_ros.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:36:11
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - True, Pca - False, Oversampling - smote (5 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_smote.csv
# Loaded ./data/y_train_scaled_smote.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:38:54
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - True, Pca - False, Oversampling - adasyn (6 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_adasyn.csv
# Loaded ./data/y_train_scaled_adasyn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:41:29
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - True, Pca - False, Oversampling - rus (7 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_rus.csv
# Loaded ./data/y_train_scaled_rus.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:41:56
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - True, Pca - False, Oversampling - nm-3 (8 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_nm-3.csv
# Loaded ./data/y_train_scaled_nm-3.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:42:18
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - True, Pca - False, Oversampling - cnn (9 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_cnn.csv
# Loaded ./data/y_train_scaled_cnn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:42:49
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - True, Pca - False, Oversampling - ros (10 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_ros.csv
# Loaded ./data/y_train_scaled_ros.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:45:05
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - True, Pca - False, Oversampling - smote (11 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_smote.csv
# Loaded ./data/y_train_scaled_smote.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:47:29
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - True, Pca - False, Oversampling - adasyn (12 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_adasyn.csv
# Loaded ./data/y_train_scaled_adasyn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:50:07
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - False, Pca - False, Oversampling - rus (13 out of 48)
# Training begins...
# Loaded ./data/X_train_rus.csv
# Loaded ./data/y_train_rus.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:50:35
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - False, Pca - False, Oversampling - nm-3 (14 out of 48)
# Training begins...
# Loaded ./data/X_train_nm-3.csv
# Loaded ./data/y_train_nm-3.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:51:01
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - False, Pca - False, Oversampling - cnn (15 out of 48)
# Training begins...
# Loaded ./data/X_train_cnn.csv
# Loaded ./data/y_train_cnn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:51:28
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - False, Pca - False, Oversampling - ros (16 out of 48)
# Training begins...
# Loaded ./data/X_train_ros.csv
# Loaded ./data/y_train_ros.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:53:52
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - False, Pca - False, Oversampling - smote (17 out of 48)
# Training begins...
# Loaded ./data/X_train_smote.csv
# Loaded ./data/y_train_smote.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:56:28
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - False, Pca - False, Oversampling - adasyn (18 out of 48)
# Training begins...
# Loaded ./data/X_train_adasyn.csv
# Loaded ./data/y_train_adasyn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:59:05
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - False, Pca - False, Oversampling - rus (19 out of 48)
# Training begins...
# Loaded ./data/X_train_rus.csv
# Loaded ./data/y_train_rus.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:59:32
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - False, Pca - False, Oversampling - nm-3 (20 out of 48)
# Training begins...
# Loaded ./data/X_train_nm-3.csv
# Loaded ./data/y_train_nm-3.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 11:59:59
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - False, Pca - False, Oversampling - cnn (21 out of 48)
# Training begins...
# Loaded ./data/X_train_cnn.csv
# Loaded ./data/y_train_cnn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:00:26
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - False, Pca - False, Oversampling - ros (22 out of 48)
# Training begins...
# Loaded ./data/X_train_ros.csv
# Loaded ./data/y_train_ros.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:02:51
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - False, Pca - False, Oversampling - smote (23 out of 48)
# Training begins...
# Loaded ./data/X_train_smote.csv
# Loaded ./data/y_train_smote.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:05:32
#
# Starting Algorithm - Random Forest, Autotuning - True, Scaling - False, Pca - False, Oversampling - adasyn (24 out of 48)
# Training begins...
# Loaded ./data/X_train_adasyn.csv
# Loaded ./data/y_train_adasyn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:07:50
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - True, Pca - False, Oversampling - rus (25 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_rus.csv
# Loaded ./data/y_train_scaled_rus.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:07:50
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - True, Pca - False, Oversampling - nm-3 (26 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_nm-3.csv
# Loaded ./data/y_train_scaled_nm-3.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:07:51
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - True, Pca - False, Oversampling - cnn (27 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_cnn.csv
# Loaded ./data/y_train_scaled_cnn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:07:51
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - True, Pca - False, Oversampling - ros (28 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_ros.csv
# Loaded ./data/y_train_scaled_ros.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:07:53
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - True, Pca - False, Oversampling - smote (29 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_smote.csv
# Loaded ./data/y_train_scaled_smote.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:07:56
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - True, Pca - False, Oversampling - adasyn (30 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_adasyn.csv
# Loaded ./data/y_train_scaled_adasyn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:07:58
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - True, Pca - False, Oversampling - rus (31 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_rus.csv
# Loaded ./data/y_train_scaled_rus.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:07:58
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - True, Pca - False, Oversampling - nm-3 (32 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_nm-3.csv
# Loaded ./data/y_train_scaled_nm-3.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:07:58
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - True, Pca - False, Oversampling - cnn (33 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_cnn.csv
# Loaded ./data/y_train_scaled_cnn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:07:59
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - True, Pca - False, Oversampling - ros (34 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_ros.csv
# Loaded ./data/y_train_scaled_ros.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:01
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - True, Pca - False, Oversampling - smote (35 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_smote.csv
# Loaded ./data/y_train_scaled_smote.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:03
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - True, Pca - False, Oversampling - adasyn (36 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_adasyn.csv
# Loaded ./data/y_train_scaled_adasyn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:05
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - False, Pca - False, Oversampling - rus (37 out of 48)
# Training begins...
# Loaded ./data/X_train_rus.csv
# Loaded ./data/y_train_rus.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:06
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - False, Pca - False, Oversampling - nm-3 (38 out of 48)
# Training begins...
# Loaded ./data/X_train_nm-3.csv
# Loaded ./data/y_train_nm-3.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:06
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - False, Pca - False, Oversampling - cnn (39 out of 48)
# Training begins...
# Loaded ./data/X_train_cnn.csv
# Loaded ./data/y_train_cnn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:07
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - False, Pca - False, Oversampling - ros (40 out of 48)
# Training begins...
# Loaded ./data/X_train_ros.csv
# Loaded ./data/y_train_ros.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:09
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - False, Pca - False, Oversampling - smote (41 out of 48)
# Training begins...
# Loaded ./data/X_train_smote.csv
# Loaded ./data/y_train_smote.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:11
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - False, Pca - False, Oversampling - adasyn (42 out of 48)
# Training begins...
# Loaded ./data/X_train_adasyn.csv
# Loaded ./data/y_train_adasyn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:13
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - False, Pca - False, Oversampling - rus (43 out of 48)
# Training begins...
# Loaded ./data/X_train_rus.csv
# Loaded ./data/y_train_rus.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:14
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - False, Pca - False, Oversampling - nm-3 (44 out of 48)
# Training begins...
# Loaded ./data/X_train_nm-3.csv
# Loaded ./data/y_train_nm-3.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:14
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - False, Pca - False, Oversampling - cnn (45 out of 48)
# Training begins...
# Loaded ./data/X_train_cnn.csv
# Loaded ./data/y_train_cnn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:15
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - False, Pca - False, Oversampling - ros (46 out of 48)
# Training begins...
# Loaded ./data/X_train_ros.csv
# Loaded ./data/y_train_ros.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:17
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - False, Pca - False, Oversampling - smote (47 out of 48)
# Training begins...
# Loaded ./data/X_train_smote.csv
# Loaded ./data/y_train_smote.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:19
#
# Starting Algorithm - Random Forest, Autotuning - False, Scaling - False, Pca - False, Oversampling - adasyn (48 out of 48)
# Training begins...
# Loaded ./data/X_train_adasyn.csv
# Loaded ./data/y_train_adasyn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:08:21

# %%
rf_results
# Out:
#         Algorithm  Non-pulsar precision  Non-pulsar recall  Non-pulsar F1  \
# 4   Random Forest              0.987887           0.990327       0.989106
# 1   Random Forest              0.985096           0.993003       0.989034
# 40  Random Forest              0.986675           0.990533       0.988600
# 7   Random Forest              0.985090           0.992591       0.988826
# 27  Random Forest              0.985487           0.992179       0.988822
# 45  Random Forest              0.985487           0.992179       0.988822
# 10  Random Forest              0.987074           0.990121       0.988595
# 33  Random Forest              0.985487           0.992179       0.988822
# 46  Random Forest              0.986675           0.990533       0.988600
# 39  Random Forest              0.985487           0.992179       0.988822
# 22  Random Forest              0.986869           0.989916       0.988390
# 13  Random Forest              0.986470           0.990327       0.988395
# 16  Random Forest              0.986869           0.989916       0.988390
# 8   Random Forest              0.987664           0.988681       0.988172
# 15  Random Forest              0.986270           0.990533       0.988397
# 3   Random Forest              0.986270           0.990533       0.988397
# 19  Random Forest              0.986667           0.989916       0.988288
# 21  Random Forest              0.986270           0.990533       0.988397
# 34  Random Forest              0.986262           0.989916       0.988085
# 38  Random Forest              0.988058           0.987652       0.987855
# 44  Random Forest              0.988058           0.987652       0.987855
# 28  Random Forest              0.986262           0.989916       0.988085
# 47  Random Forest              0.988660           0.986829       0.987743
# 41  Random Forest              0.988660           0.986829       0.987743
# 5   Random Forest              0.989665           0.985388       0.987522
# 9   Random Forest              0.985662           0.990327       0.987989
# 32  Random Forest              0.987251           0.988063       0.987657
# 11  Random Forest              0.989056           0.985800       0.987425
# 20  Random Forest              0.988054           0.987240       0.987647
# 17  Random Forest              0.990066           0.984565       0.987308
# 26  Random Forest              0.987251           0.988063       0.987657
# 29  Random Forest              0.988653           0.986211       0.987430
# 14  Random Forest              0.988051           0.987034       0.987542
# 35  Random Forest              0.988653           0.986211       0.987430
# 2   Random Forest              0.987649           0.987446       0.987548
# 23  Random Forest              0.990265           0.983947       0.987096
# 31  Random Forest              0.985546           0.982301       0.983921
# 25  Random Forest              0.985546           0.982301       0.983921
# 43  Random Forest              0.986921           0.978391       0.982637
# 37  Random Forest              0.986921           0.978391       0.982637
# 18  Random Forest              0.992415           0.969335       0.980739
# 0   Random Forest              0.992410           0.968718       0.980421
# 6   Random Forest              0.992407           0.968306       0.980208
# 12  Random Forest              0.992819           0.967483       0.979987
# 42  Random Forest              0.992599           0.966042       0.979141
# 36  Random Forest              0.992599           0.966042       0.979141
# 30  Random Forest              0.992599           0.966042       0.979141
# 24  Random Forest              0.992599           0.966042       0.979141
#
#     Pulsar precision  Pulsar recall  Pulsar F1  Weighted precision  \
# 4           0.905622       0.884314   0.894841            0.980073
# 1           0.927813       0.856863   0.890928            0.979655
# 40          0.906314       0.872549   0.889111            0.979041
# 7           0.923890       0.856863   0.889115            0.979277
# 27          0.920335       0.860784   0.889564            0.979298
# 45          0.920335       0.860784   0.889564            0.979298
# 10          0.903030       0.876471   0.889552            0.979091
# 33          0.920335       0.860784   0.889564            0.979298
# 46          0.906314       0.872549   0.889111            0.979041
# 39          0.920335       0.860784   0.889564            0.979298
# 22          0.901010       0.874510   0.887562            0.978713
# 13          0.904277       0.870588   0.887113            0.978662
# 16          0.901010       0.874510   0.887562            0.978713
# 8           0.891089       0.882353   0.886700            0.978491
# 15          0.905930       0.868627   0.886887            0.978639
# 3           0.905930       0.868627   0.886887            0.978639
# 19          0.900810       0.872549   0.886454            0.978511
# 21          0.905930       0.868627   0.886887            0.978639
# 34          0.900407       0.868627   0.884232            0.978107
# 38          0.882812       0.886275   0.884540            0.978061
# 44          0.882812       0.886275   0.884540            0.978061
# 28          0.900407       0.868627   0.884232            0.978107
# 47          0.876686       0.892157   0.884354            0.978023
# 41          0.876686       0.892157   0.884354            0.978023
# 5           0.866290       0.901961   0.883766            0.977946
# 9           0.903491       0.862745   0.882648            0.977856
# 32          0.885375       0.878431   0.881890            0.977574
# 11          0.868821       0.896078   0.882239            0.977635
# 20          0.879377       0.886275   0.882812            0.977730
# 17          0.860335       0.905882   0.882521            0.977743
# 26          0.885375       0.878431   0.881890            0.977574
# 29          0.871648       0.892157   0.881783            0.977538
# 14          0.877670       0.886275   0.881951            0.977566
# 35          0.871648       0.892157   0.881783            0.977538
# 2           0.880626       0.882353   0.881489            0.977483
# 23          0.855823       0.907843   0.881066            0.977494
# 31          0.836502       0.862745   0.849421            0.971388
# 25          0.836502       0.862745   0.849421            0.971388
# 43          0.809783       0.876471   0.841808            0.970095
# 37          0.809783       0.876471   0.841808            0.970095
# 18          0.760835       0.929412   0.836717            0.970417
# 0           0.757188       0.929412   0.834507            0.970066
# 6           0.754777       0.929412   0.833040            0.969834
# 12          0.750789       0.933333   0.832168            0.969829
# 42          0.742188       0.931373   0.826087            0.968812
# 36          0.742188       0.931373   0.826087            0.968812
# 30          0.742188       0.931373   0.826087            0.968812
# 24          0.742188       0.931373   0.826087            0.968812
#
#     Weighted recall  Weighted F1  Matthews corrcoefficient  Cohen's Kappa  \
# 4          0.980257     0.980152                     0.884          0.884
# 1          0.980071     0.979714                     0.881          0.880
# 40         0.979326     0.979150                     0.878          0.878
# 7          0.979698     0.979355                     0.879          0.878
# 27         0.979698     0.979393                     0.879          0.878
# 45         0.979698     0.979393                     0.879          0.878
# 10         0.979326     0.979187                     0.878          0.878
# 33         0.979698     0.979393                     0.879          0.878
# 46         0.979326     0.979150                     0.878          0.878
# 39         0.979698     0.979393                     0.879          0.878
# 22         0.978953     0.978812                     0.876          0.876
# 13         0.978953     0.978774                     0.876          0.876
# 16         0.978953     0.978812                     0.876          0.876
# 8          0.978581     0.978533                     0.875          0.875
# 15         0.978953     0.978755                     0.876          0.875
# 3          0.978953     0.978755                     0.876          0.875
# 19         0.978767     0.978615                     0.875          0.875
# 21         0.978953     0.978755                     0.876          0.875
# 34         0.978394     0.978220                     0.872          0.872
# 38         0.978022     0.978041                     0.872          0.872
# 44         0.978022     0.978041                     0.872          0.872
# 28         0.978394     0.978220                     0.872          0.872
# 47         0.977836     0.977922                     0.872          0.872
# 41         0.977836     0.977922                     0.872          0.872
# 5          0.977463     0.977666                     0.872          0.871
# 9          0.978208     0.977983                     0.871          0.871
# 32         0.977649     0.977610                     0.870          0.870
# 11         0.977277     0.977434                     0.870          0.870
# 20         0.977649     0.977689                     0.870          0.870
# 17         0.977091     0.977354                     0.870          0.870
# 26         0.977649     0.977610                     0.870          0.870
# 29         0.977277     0.977395                     0.869          0.869
# 14         0.977463     0.977512                     0.870          0.869
# 35         0.977277     0.977395                     0.869          0.869
# 2          0.977463     0.977473                     0.869          0.869
# 23         0.976718     0.977024                     0.869          0.868
# 31         0.970944     0.971145                     0.833          0.833
# 25         0.970944     0.971145                     0.833          0.833
# 43         0.968709     0.969260                     0.825          0.824
# 37         0.968709     0.969260                     0.825          0.824
# 18         0.965543     0.967059                     0.823          0.818
# 0          0.964984     0.966560                     0.821          0.815
# 6          0.964612     0.966229                     0.819          0.813
# 12         0.964239     0.965946                     0.818          0.812
# 42         0.962749     0.964602                     0.812          0.806
# 36         0.962749     0.964602                     0.812          0.806
# 30         0.962749     0.964602                     0.812          0.806
# 24         0.962749     0.964602                     0.812          0.806
#
#                                            Parameters    PCA Tuning Scaling  \
# 4   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True    True
# 1   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True    True
# 40  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False   False
# 7   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True    True
# 27  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False    True
# 45  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False   False
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True    True
# 33  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False    True
# 46  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False   False
# 39  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False   False
# 22  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True   False
# 13  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True   False
# 16  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True   False
# 8   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True    True
# 15  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True   False
# 3   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True    True
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True   False
# 21  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True   False
# 34  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False    True
# 38  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False   False
# 44  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False   False
# 28  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False    True
# 47  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False   False
# 41  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False   False
# 5   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True    True
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True    True
# 32  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False    True
# 11  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True    True
# 20  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True   False
# 17  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True   False
# 26  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False    True
# 29  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False    True
# 14  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True   False
# 35  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False    True
# 2   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True    True
# 23  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True   False
# 31  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False    True
# 25  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False    True
# 43  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False   False
# 37  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False   False
# 18  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True   False
# 0   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True    True
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True    True
# 12  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False   True   False
# 42  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False   False
# 36  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False   False
# 30  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False    True
# 24  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...  False  False    True
#
#    Sampling
# 4     smote
# 1      nm-3
# 40    smote
# 7      nm-3
# 27      ros
# 45      ros
# 10    smote
# 33      ros
# 46    smote
# 39      ros
# 22    smote
# 13     nm-3
# 16    smote
# 8       cnn
# 15      ros
# 3       ros
# 19     nm-3
# 21      ros
# 34    smote
# 38      cnn
# 44      cnn
# 28    smote
# 47   adasyn
# 41   adasyn
# 5    adasyn
# 9       ros
# 32      cnn
# 11   adasyn
# 20      cnn
# 17   adasyn
# 26      cnn
# 29   adasyn
# 14      cnn
# 35   adasyn
# 2       cnn
# 23   adasyn
# 31     nm-3
# 25     nm-3
# 43     nm-3
# 37     nm-3
# 18      rus
# 0       rus
# 6       rus
# 12      rus
# 42      rus
# 36      rus
# 30      rus
# 24      rus
