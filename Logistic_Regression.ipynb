# %%
from itertools import product
from datetime import datetime

import pandas as pd

from model import choose_dataset, train_model, add_new_row, plot_conf_matrix

import warnings
warnings.filterwarnings('ignore')

# %%
tune_list = [True, False]
scaling_list = [True, False]
pca_list = [True, False]
sampling_list = ['rus', 'nm-3', 'cnn', 'ros', 'smote', 'adasyn']

lr_results = pd.DataFrame(columns=['Algorithm', 'Non-pulsar precision', 'Non-pulsar recall', 'Non-pulsar F1', 'Pulsar precision', 'Pulsar recall', 'Pulsar F1', 'Weighted precision', 'Weighted recall', 'Weighted F1', 'Matthews corrcoefficient', "Cohen's Kappa", 'Parameters', 'PCA', 'Tuning', 'Scaling', 'Sampling'])

n = 0

print('Start time at', datetime.now().strftime("%H:%M:%S"))

for tuning, scaling, pca, sampling in product(tune_list, scaling_list, pca_list, sampling_list):
    n += 1
    print('Starting Algorithm - Logistic Regression, Autotuning - {}, Scaling - {}, Pca - {}, Sampling - {} ({} out of {})'.format(
        tuning, scaling, pca, sampling, n, len(list(product(tune_list, scaling_list, pca_list, sampling_list)))))
    

    algorithm, preds, y_test = train_model(algo='lr', pca=pca, tuning=tuning, scaling=scaling, sampling=sampling, n_jobs=7, scoring='cohen', verbose=0)     
    row = add_new_row(algorithm, preds, y_test)
    row['Algorithm'] = 'Logistic Regression'
    row['PCA'] = pca
    row['Tuning'] = tuning
    row['Scaling'] = scaling
    row['Sampling'] = sampling
    lr_results.loc[len(lr_results)] = row
    print('Done at', datetime.now().strftime("%H:%M:%S"), '\n')
    lr_results.to_csv('./results/lr_results.csv', index=False)
# Out:
# Start time at 12:00:55
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - True, Pca - True, Sampling - rus (1 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_rus.csv
# Loaded ./data/y_train_scaled_pca_rus.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:01:03
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - True, Pca - True, Sampling - nm-3 (2 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_nm-3.csv
# Loaded ./data/y_train_scaled_pca_nm-3.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:01:09
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - True, Pca - True, Sampling - cnn (3 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_cnn.csv
# Loaded ./data/y_train_scaled_pca_cnn.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:01:15
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - True, Pca - True, Sampling - ros (4 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_ros.csv
# Loaded ./data/y_train_scaled_pca_ros.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:01:31
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - True, Pca - True, Sampling - smote (5 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_smote.csv
# Loaded ./data/y_train_scaled_pca_smote.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:01:47
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - True, Pca - True, Sampling - adasyn (6 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_adasyn.csv
# Loaded ./data/y_train_scaled_pca_adasyn.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:02:02
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - True, Pca - False, Sampling - rus (7 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_rus.csv
# Loaded ./data/y_train_scaled_rus.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:02:13
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - True, Pca - False, Sampling - nm-3 (8 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_nm-3.csv
# Loaded ./data/y_train_scaled_nm-3.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:02:23
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - True, Pca - False, Sampling - cnn (9 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_cnn.csv
# Loaded ./data/y_train_scaled_cnn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:02:34
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - True, Pca - False, Sampling - ros (10 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_ros.csv
# Loaded ./data/y_train_scaled_ros.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:03:15
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - True, Pca - False, Sampling - smote (11 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_smote.csv
# Loaded ./data/y_train_scaled_smote.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:03:54
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - True, Pca - False, Sampling - adasyn (12 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_adasyn.csv
# Loaded ./data/y_train_scaled_adasyn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:04:36
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - False, Pca - True, Sampling - rus (13 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_rus.csv
# Loaded ./data/y_train_pca_rus.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:04:44
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - False, Pca - True, Sampling - nm-3 (14 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_nm-3.csv
# Loaded ./data/y_train_pca_nm-3.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:04:51
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - False, Pca - True, Sampling - cnn (15 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_cnn.csv
# Loaded ./data/y_train_pca_cnn.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:04:59
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - False, Pca - True, Sampling - ros (16 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_ros.csv
# Loaded ./data/y_train_pca_ros.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:05:24
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - False, Pca - True, Sampling - smote (17 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_smote.csv
# Loaded ./data/y_train_pca_smote.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:05:50
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - False, Pca - True, Sampling - adasyn (18 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_adasyn.csv
# Loaded ./data/y_train_pca_adasyn.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:06:12
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - False, Pca - False, Sampling - rus (19 out of 48)
# Training begins...
# Loaded ./data/X_train_rus.csv
# Loaded ./data/y_train_rus.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:06:37
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - False, Pca - False, Sampling - nm-3 (20 out of 48)
# Training begins...
# Loaded ./data/X_train_nm-3.csv
# Loaded ./data/y_train_nm-3.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:07:03
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - False, Pca - False, Sampling - cnn (21 out of 48)
# Training begins...
# Loaded ./data/X_train_cnn.csv
# Loaded ./data/y_train_cnn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:07:30
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - False, Pca - False, Sampling - ros (22 out of 48)
# Training begins...
# Loaded ./data/X_train_ros.csv
# Loaded ./data/y_train_ros.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:09:37
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - False, Pca - False, Sampling - smote (23 out of 48)
# Training begins...
# Loaded ./data/X_train_smote.csv
# Loaded ./data/y_train_smote.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:11:45
#
# Starting Algorithm - Logistic Regression, Autotuning - True, Scaling - False, Pca - False, Sampling - adasyn (24 out of 48)
# Training begins...
# Loaded ./data/X_train_adasyn.csv
# Loaded ./data/y_train_adasyn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 12:14:32
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - True, Pca - True, Sampling - rus (25 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_rus.csv
# Loaded ./data/y_train_scaled_pca_rus.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:32
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - True, Pca - True, Sampling - nm-3 (26 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_nm-3.csv
# Loaded ./data/y_train_scaled_pca_nm-3.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:32
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - True, Pca - True, Sampling - cnn (27 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_cnn.csv
# Loaded ./data/y_train_scaled_pca_cnn.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:32
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - True, Pca - True, Sampling - ros (28 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_ros.csv
# Loaded ./data/y_train_scaled_pca_ros.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:32
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - True, Pca - True, Sampling - smote (29 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_smote.csv
# Loaded ./data/y_train_scaled_pca_smote.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:33
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - True, Pca - True, Sampling - adasyn (30 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_adasyn.csv
# Loaded ./data/y_train_scaled_pca_adasyn.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:33
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - True, Pca - False, Sampling - rus (31 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_rus.csv
# Loaded ./data/y_train_scaled_rus.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:33
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - True, Pca - False, Sampling - nm-3 (32 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_nm-3.csv
# Loaded ./data/y_train_scaled_nm-3.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:33
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - True, Pca - False, Sampling - cnn (33 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_cnn.csv
# Loaded ./data/y_train_scaled_cnn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:33
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - True, Pca - False, Sampling - ros (34 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_ros.csv
# Loaded ./data/y_train_scaled_ros.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:33
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - True, Pca - False, Sampling - smote (35 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_smote.csv
# Loaded ./data/y_train_scaled_smote.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:33
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - True, Pca - False, Sampling - adasyn (36 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_adasyn.csv
# Loaded ./data/y_train_scaled_adasyn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:33
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - False, Pca - True, Sampling - rus (37 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_rus.csv
# Loaded ./data/y_train_pca_rus.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:33
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - False, Pca - True, Sampling - nm-3 (38 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_nm-3.csv
# Loaded ./data/y_train_pca_nm-3.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:33
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - False, Pca - True, Sampling - cnn (39 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_cnn.csv
# Loaded ./data/y_train_pca_cnn.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:33
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - False, Pca - True, Sampling - ros (40 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_ros.csv
# Loaded ./data/y_train_pca_ros.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:34
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - False, Pca - True, Sampling - smote (41 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_smote.csv
# Loaded ./data/y_train_pca_smote.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:34
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - False, Pca - True, Sampling - adasyn (42 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_adasyn.csv
# Loaded ./data/y_train_pca_adasyn.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:34
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - False, Pca - False, Sampling - rus (43 out of 48)
# Training begins...
# Loaded ./data/X_train_rus.csv
# Loaded ./data/y_train_rus.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:34
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - False, Pca - False, Sampling - nm-3 (44 out of 48)
# Training begins...
# Loaded ./data/X_train_nm-3.csv
# Loaded ./data/y_train_nm-3.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:34
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - False, Pca - False, Sampling - cnn (45 out of 48)
# Training begins...
# Loaded ./data/X_train_cnn.csv
# Loaded ./data/y_train_cnn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:34
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - False, Pca - False, Sampling - ros (46 out of 48)
# Training begins...
# Loaded ./data/X_train_ros.csv
# Loaded ./data/y_train_ros.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:34
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - False, Pca - False, Sampling - smote (47 out of 48)
# Training begins...
# Loaded ./data/X_train_smote.csv
# Loaded ./data/y_train_smote.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:34
#
# Starting Algorithm - Logistic Regression, Autotuning - False, Scaling - False, Pca - False, Sampling - adasyn (48 out of 48)
# Training begins...
# Loaded ./data/X_train_adasyn.csv
# Loaded ./data/y_train_adasyn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 12:14:35

# %%
lr_results.sort_values(by="Cohen's Kappa", ascending=False).reset_index(drop=True)
# Out:
#               Algorithm  Non-pulsar precision  Non-pulsar recall  \
# 0   Logistic Regression              0.986888           0.991356
# 1   Logistic Regression              0.986686           0.991356
# 2   Logistic Regression              0.986686           0.991356
# 3   Logistic Regression              0.986885           0.991150
# 4   Logistic Regression              0.986484           0.991356
# 5   Logistic Regression              0.986279           0.991150
# 6   Logistic Regression              0.987672           0.989298
# 7   Logistic Regression              0.986279           0.991150
# 8   Logistic Regression              0.987472           0.989504
# 9   Logistic Regression              0.985466           0.990739
# 10  Logistic Regression              0.990066           0.984565
# 11  Logistic Regression              0.989256           0.985388
# 12  Logistic Regression              0.989252           0.984976
# 13  Logistic Regression              0.986645           0.988269
# 14  Logistic Regression              0.987833           0.985800
# 15  Logistic Regression              0.988820           0.982918
# 16  Logistic Regression              0.986203           0.985594
# 17  Logistic Regression              0.986603           0.985182
# 18  Logistic Regression              0.986200           0.985388
# 19  Logistic Regression              0.987739           0.978185
# 20  Logistic Regression              0.980592           0.987858
# 21  Logistic Regression              0.977300           0.992385
# 22  Logistic Regression              0.992225           0.971805
# 23  Logistic Regression              0.980200           0.988269
# 24  Logistic Regression              0.980585           0.987446
# 25  Logistic Regression              0.980585           0.987446
# 26  Logistic Regression              0.977102           0.992385
# 27  Logistic Regression              0.992224           0.971599
# 28  Logistic Regression              0.976904           0.992385
# 29  Logistic Regression              0.976904           0.992385
# 30  Logistic Regression              0.992204           0.969129
# 31  Logistic Regression              0.980344           0.985388
# 32  Logistic Regression              0.980513           0.983742
# 33  Logistic Regression              0.991763           0.966454
# 34  Logistic Regression              0.985391           0.957810
# 35  Logistic Regression              0.985384           0.957399
# 36  Logistic Regression              0.982874           0.933114
# 37  Logistic Regression              0.982856           0.932085
# 38  Logistic Regression              0.983191           0.926940
# 39  Logistic Regression              0.983191           0.926940
# 40  Logistic Regression              0.973365           0.940111
# 41  Logistic Regression              0.973549           0.939288
# 42  Logistic Regression              0.950336           0.960897
# 43  Logistic Regression              0.950142           0.960897
# 44  Logistic Regression              0.950142           0.960897
# 45  Logistic Regression              0.949756           0.960897
# 46  Logistic Regression              0.948136           0.963161
# 47  Logistic Regression              0.947955           0.963367
#
#     Non-pulsar F1  Pulsar precision  Pulsar recall  Pulsar F1  \
# 0        0.989117          0.913934       0.874510   0.893788
# 1        0.989016          0.913758       0.872549   0.892678
# 2        0.989016          0.913758       0.872549   0.892678
# 3        0.989013          0.912065       0.874510   0.892893
# 4        0.988914          0.913580       0.870588   0.891566
# 5        0.988709          0.911523       0.868627   0.889558
# 6        0.988484          0.896414       0.882353   0.889328
# 7        0.988709          0.911523       0.868627   0.889558
# 8        0.988487          0.898000       0.880392   0.889109
# 9        0.988095          0.907025       0.860784   0.883300
# 10       0.987308          0.860335       0.905882   0.882521
# 11       0.987318          0.865784       0.898039   0.881617
# 12       0.987109          0.862524       0.898039   0.879923
# 13       0.987456          0.886454       0.872549   0.879447
# 14       0.986815          0.867308       0.884314   0.875728
# 15       0.985860          0.846011       0.894118   0.869399
# 16       0.985898          0.863548       0.868627   0.866080
# 17       0.985892          0.860735       0.872549   0.866602
# 18       0.985794          0.861868       0.868627   0.865234
# 19       0.982939          0.809695       0.884314   0.845361
# 20       0.984212          0.875527       0.813725   0.843496
# 21       0.984785          0.914943       0.780392   0.842328
# 22       0.981909          0.775410       0.927451   0.844643
# 23       0.984218          0.878723       0.809804   0.842857
# 24       0.984003          0.871849       0.813725   0.841785
# 25       0.984003          0.871849       0.813725   0.841785
# 26       0.984685          0.914747       0.778431   0.841102
# 27       0.981803          0.774141       0.927451   0.843889
# 28       0.984584          0.914550       0.776471   0.839873
# 29       0.984584          0.914550       0.776471   0.839873
# 30       0.980531          0.759230       0.927451   0.834951
# 31       0.982859          0.853608       0.811765   0.832161
# 32       0.982125          0.840081       0.813725   0.826693
# 33       0.978945          0.742902       0.923529   0.823427
# 34       0.971405          0.682663       0.864706   0.762976
# 35       0.971190          0.680556       0.864706   0.761658
# 36       0.957348          0.570106       0.845098   0.680885
# 37       0.956797          0.566360       0.845098   0.678206
# 38       0.954237          0.549492       0.849020   0.667180
# 39       0.954237          0.549492       0.849020   0.667180
# 40       0.956449          0.569527       0.754902   0.649241
# 41       0.956112          0.566814       0.756863   0.648195
# 42       0.955587          0.583333       0.521569   0.550725
# 43       0.955490          0.582418       0.519608   0.549223
# 44       0.955490          0.582418       0.519608   0.549223
# 45       0.955294          0.580574       0.515686   0.546210
# 46       0.955590          0.586605       0.498039   0.538706
# 47       0.955599          0.587007       0.496078   0.537726
#
#     Weighted precision  Weighted recall  Weighted F1  \
# 0             0.979958         0.980257     0.980062
# 1             0.979758         0.980071     0.979864
# 2             0.979758         0.980071     0.979864
# 3             0.979778         0.980071     0.979883
# 4             0.979559         0.979885     0.979667
# 5             0.979178         0.979512     0.979290
# 6             0.979004         0.979140     0.979066
# 7             0.979178         0.979512     0.979290
# 8             0.978973         0.979140     0.979047
# 9             0.978015         0.978394     0.978141
# 10            0.977743         0.977091     0.977354
# 11            0.977528         0.977091     0.977278
# 12            0.977214         0.976718     0.976928
# 13            0.977128         0.977277     0.977196
# 14            0.976384         0.976159     0.976263
# 15            0.975255         0.974483     0.974798
# 16            0.974552         0.974483     0.974517
# 17            0.974647         0.974483     0.974561
# 18            0.974390         0.974297     0.974342
# 19            0.970827         0.969268     0.969870
# 20            0.970612         0.971317     0.970845
# 21            0.971377         0.972248     0.971253
# 22            0.971630         0.967592     0.968870
# 23            0.970561         0.971317     0.970790
# 24            0.970256         0.970944     0.970494
# 25            0.970256         0.970944     0.970494
# 26            0.971179         0.972062     0.971046
# 27            0.971508         0.967405     0.968703
# 28            0.970981         0.971876     0.970838
# 29            0.970981         0.971876     0.970838
# 30            0.970074         0.965170     0.966702
# 31            0.968305         0.968896     0.968545
# 32            0.967173         0.967592     0.967360
# 33            0.968124         0.962377     0.964173
# 34            0.956635         0.948966     0.951606
# 35            0.956429         0.948594     0.951287
# 36            0.943666         0.924753     0.931087
# 37            0.943293         0.923822     0.930334
# 38            0.941994         0.919538     0.926970
# 39            0.941994         0.919538     0.926970
# 40            0.935004         0.922518     0.927267
# 41            0.934914         0.921959     0.926863
# 42            0.915474         0.919166     0.917130
# 43            0.915212         0.918979     0.916898
# 44            0.915212         0.918979     0.916898
# 45            0.914687         0.918607     0.916435
# 46            0.913794         0.918979     0.915990
# 47            0.913668         0.918979     0.915905
#
#     Matthews corrcoefficient  Cohen's Kappa  \
# 0                      0.883          0.883
# 1                      0.882          0.882
# 2                      0.882          0.882
# 3                      0.882          0.882
# 4                      0.881          0.880
# 5                      0.879          0.878
# 6                      0.878          0.878
# 7                      0.879          0.878
# 8                      0.878          0.878
# 9                      0.872          0.871
# 10                     0.870          0.870
# 11                     0.869          0.869
# 12                     0.867          0.867
# 13                     0.867          0.867
# 14                     0.863          0.863
# 15                     0.856          0.855
# 16                     0.852          0.852
# 17                     0.853          0.852
# 18                     0.851          0.851
# 19                     0.829          0.828
# 20                     0.828          0.828
# 21                     0.830          0.827
# 22                     0.831          0.827
# 23                     0.828          0.827
# 24                     0.826          0.826
# 25                     0.826          0.826
# 26                     0.829          0.826
# 27                     0.830          0.826
# 28                     0.828          0.825
# 29                     0.828          0.825
# 30                     0.821          0.816
# 31                     0.815          0.815
# 32                     0.809          0.809
# 33                     0.809          0.803
# 34                     0.741          0.735
# 35                     0.740          0.733
# 36                     0.656          0.640
# 37                     0.653          0.637
# 38                     0.643          0.624
# 39                     0.643          0.624
# 40                     0.614          0.607
# 41                     0.613          0.605
# 42                     0.507          0.506
# 43                     0.506          0.505
# 44                     0.506          0.505
# 45                     0.503          0.502
# 46                     0.497          0.495
# 47                     0.496          0.494
#
#                                            Parameters    PCA Tuning Scaling  \
# 0   {'C': 9.79795918367347, 'class_weight': None, ...  False   True   False
# 1   {'C': 1.0, 'class_weight': None, 'dual': False...  False  False    True
# 2   {'C': 1.0, 'class_weight': None, 'dual': False...  False  False    True
# 3   {'C': 3.736734693877551, 'class_weight': None,...  False   True    True
# 4   {'C': 0.7061224489795919, 'class_weight': None...  False   True    True
# 5   {'C': 1.0, 'class_weight': None, 'dual': False...  False  False   False
# 6   {'C': 1.0, 'class_weight': None, 'dual': False...  False  False    True
# 7   {'C': 5.353061224489796, 'class_weight': None,...  False   True   False
# 8   {'C': 5.555102040816326, 'class_weight': None,...  False   True    True
# 9   {'C': 1.0, 'class_weight': None, 'dual': False...  False  False   False
# 10  {'C': 9.191836734693878, 'class_weight': None,...  False   True   False
# 11  {'C': 1.0, 'class_weight': None, 'dual': False...  False  False    True
# 12  {'C': 4.3428571428571425, 'class_weight': None...  False   True    True
# 13  {'C': 1.0, 'class_weight': None, 'dual': False...  False  False   False
# 14  {'C': 8.989795918367347, 'class_weight': None,...  False   True   False
# 15  {'C': 1.0, 'class_weight': None, 'dual': False...  False  False   False
# 16  {'C': 1.0, 'class_weight': None, 'dual': False...  False  False    True
# 17  {'C': 3.1306122448979594, 'class_weight': None...  False   True    True
# 18  {'C': 1.0, 'class_weight': None, 'dual': False...  False  False   False
# 19  {'C': 2.5244897959183676, 'class_weight': None...  False   True   False
# 20  {'C': 1.0, 'class_weight': None, 'dual': False...   True  False    True
# 21  {'C': 0.1, 'class_weight': None, 'dual': False...   True   True    True
# 22  {'C': 0.3020408163265306, 'class_weight': None...  False   True    True
# 23  {'C': 1.0, 'class_weight': None, 'dual': False...   True  False    True
# 24  {'C': 0.1, 'class_weight': None, 'dual': False...   True   True    True
# 25  {'C': 0.1, 'class_weight': None, 'dual': False...   True   True    True
# 26  {'C': 1.0, 'class_weight': None, 'dual': False...   True  False    True
# 27  {'C': 1.0, 'class_weight': None, 'dual': False...  False  False    True
# 28  {'C': 0.1, 'class_weight': None, 'dual': False...   True   True    True
# 29  {'C': 1.0, 'class_weight': None, 'dual': False...   True  False    True
# 30  {'C': 4.746938775510204, 'class_weight': None,...  False   True   False
# 31  {'C': 1.0, 'class_weight': None, 'dual': False...   True  False    True
# 32  {'C': 0.1, 'class_weight': None, 'dual': False...   True   True    True
# 33  {'C': 1.0, 'class_weight': None, 'dual': False...  False  False   False
# 34  {'C': 0.1, 'class_weight': None, 'dual': False...   True   True    True
# 35  {'C': 1.0, 'class_weight': None, 'dual': False...   True  False    True
# 36  {'C': 1.0, 'class_weight': None, 'dual': False...   True  False   False
# 37  {'C': 0.1, 'class_weight': None, 'dual': False...   True   True   False
# 38  {'C': 1.0, 'class_weight': None, 'dual': False...   True  False   False
# 39  {'C': 0.1, 'class_weight': None, 'dual': False...   True   True   False
# 40  {'C': 1.0, 'class_weight': None, 'dual': False...   True  False   False
# 41  {'C': 0.1, 'class_weight': None, 'dual': False...   True   True   False
# 42  {'C': 0.1, 'class_weight': None, 'dual': False...   True   True   False
# 43  {'C': 1.0, 'class_weight': None, 'dual': False...   True  False   False
# 44  {'C': 0.1, 'class_weight': None, 'dual': False...   True   True   False
# 45  {'C': 1.0, 'class_weight': None, 'dual': False...   True  False   False
# 46  {'C': 0.1, 'class_weight': None, 'dual': False...   True   True   False
# 47  {'C': 1.0, 'class_weight': None, 'dual': False...   True  False   False
#
#    Sampling
# 0       ros
# 1       ros
# 2     smote
# 3       ros
# 4     smote
# 5     smote
# 6       cnn
# 7     smote
# 8       cnn
# 9       ros
# 10   adasyn
# 11   adasyn
# 12   adasyn
# 13      cnn
# 14      cnn
# 15   adasyn
# 16     nm-3
# 17     nm-3
# 18     nm-3
# 19     nm-3
# 20   adasyn
# 21    smote
# 22      rus
# 23      cnn
# 24   adasyn
# 25      cnn
# 26    smote
# 27      rus
# 28      ros
# 29      ros
# 30      rus
# 31     nm-3
# 32     nm-3
# 33      rus
# 34      rus
# 35      rus
# 36      rus
# 37      rus
# 38     nm-3
# 39     nm-3
# 40      cnn
# 41      cnn
# 42    smote
# 43    smote
# 44      ros
# 45      ros
# 46   adasyn
# 47   adasyn
