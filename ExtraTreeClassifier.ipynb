# %%
from itertools import product
from datetime import datetime

import pandas as pd

from model import choose_dataset, train_model, add_new_row

import warnings
warnings.filterwarnings('ignore')

# %%
tune_list = [True, False]
scaling_list = [True, False]
pca_list = [True, False]
sampling_list = ['rus', 'nm-3', 'cnn', 'ros', 'smote', 'adasyn']

etc_results = pd.DataFrame(columns=['Algorithm', 'Non-pulsar precision', 'Non-pulsar recall', 'Non-pulsar F1', 'Pulsar precision', 'Pulsar recall', 'Pulsar F1', 'Weighted precision', 'Weighted recall', 'Weighted F1', 'Matthews corrcoefficient', "Cohen's Kappa", 'Parameters', 'PCA', 'Tuning', 'Scaling', 'Sampling'])

n = 0

print('Start time at', datetime.now().strftime("%H:%M:%S"))

for tuning, scaling, pca, sampling in product(tune_list, scaling_list, pca_list, sampling_list):
    n += 1
    print('Starting Algorithm - ExtraTreesClassifier, Autotuning - {}, Scaling - {}, Pca - {}, Oversampling - {} ({} out of {})'.format(
        tuning, scaling, pca, sampling, n, len(list(product(tune_list, scaling_list, pca_list, sampling_list)))))
    

    algorithm, preds, y_test = train_model(algo='etc', pca=pca, tuning=tuning, scaling=scaling, n_splits=5, sampling=sampling, n_jobs=7, scoring='cohen', verbose=0)     
    row = add_new_row(algorithm, preds, y_test)
    row['Algorithm'] = 'ExtraTreeClassifier'
    row['PCA'] = pca
    row['Tuning'] = tuning
    row['Scaling'] = scaling
    row['Sampling'] = sampling
    etc_results.loc[len(etc_results)] = row
    print('Done at', datetime.now().strftime("%H:%M:%S"), '\n')
    etc_results.to_csv('./results/etc_results.csv', index=False)
# Out:
# Start time at 13:13:47
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - True, Pca - True, Oversampling - rus (1 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_rus.csv
# Loaded ./data/y_train_scaled_pca_rus.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:14:15
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - True, Pca - True, Oversampling - nm-3 (2 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_nm-3.csv
# Loaded ./data/y_train_scaled_pca_nm-3.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:14:44
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - True, Pca - True, Oversampling - cnn (3 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_cnn.csv
# Loaded ./data/y_train_scaled_pca_cnn.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:15:13
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - True, Pca - True, Oversampling - ros (4 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_ros.csv
# Loaded ./data/y_train_scaled_pca_ros.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:16:07
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - True, Pca - True, Oversampling - smote (5 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_smote.csv
# Loaded ./data/y_train_scaled_pca_smote.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:17:03
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - True, Pca - True, Oversampling - adasyn (6 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_adasyn.csv
# Loaded ./data/y_train_scaled_pca_adasyn.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:17:56
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - True, Pca - False, Oversampling - rus (7 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_rus.csv
# Loaded ./data/y_train_scaled_rus.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:18:28
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - True, Pca - False, Oversampling - nm-3 (8 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_nm-3.csv
# Loaded ./data/y_train_scaled_nm-3.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:19:03
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - True, Pca - False, Oversampling - cnn (9 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_cnn.csv
# Loaded ./data/y_train_scaled_cnn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:19:37
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - True, Pca - False, Oversampling - ros (10 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_ros.csv
# Loaded ./data/y_train_scaled_ros.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:21:04
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - True, Pca - False, Oversampling - smote (11 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_smote.csv
# Loaded ./data/y_train_scaled_smote.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:22:29
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - True, Pca - False, Oversampling - adasyn (12 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_adasyn.csv
# Loaded ./data/y_train_scaled_adasyn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:23:53
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - False, Pca - True, Oversampling - rus (13 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_rus.csv
# Loaded ./data/y_train_pca_rus.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:24:22
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - False, Pca - True, Oversampling - nm-3 (14 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_nm-3.csv
# Loaded ./data/y_train_pca_nm-3.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:24:50
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - False, Pca - True, Oversampling - cnn (15 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_cnn.csv
# Loaded ./data/y_train_pca_cnn.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:25:19
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - False, Pca - True, Oversampling - ros (16 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_ros.csv
# Loaded ./data/y_train_pca_ros.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:26:15
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - False, Pca - True, Oversampling - smote (17 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_smote.csv
# Loaded ./data/y_train_pca_smote.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:27:12
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - False, Pca - True, Oversampling - adasyn (18 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_adasyn.csv
# Loaded ./data/y_train_pca_adasyn.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:28:06
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - False, Pca - False, Oversampling - rus (19 out of 48)
# Training begins...
# Loaded ./data/X_train_rus.csv
# Loaded ./data/y_train_rus.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:28:39
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - False, Pca - False, Oversampling - nm-3 (20 out of 48)
# Training begins...
# Loaded ./data/X_train_nm-3.csv
# Loaded ./data/y_train_nm-3.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:29:13
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - False, Pca - False, Oversampling - cnn (21 out of 48)
# Training begins...
# Loaded ./data/X_train_cnn.csv
# Loaded ./data/y_train_cnn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:29:43
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - False, Pca - False, Oversampling - ros (22 out of 48)
# Training begins...
# Loaded ./data/X_train_ros.csv
# Loaded ./data/y_train_ros.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:31:06
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - False, Pca - False, Oversampling - smote (23 out of 48)
# Training begins...
# Loaded ./data/X_train_smote.csv
# Loaded ./data/y_train_smote.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:32:36
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - True, Scaling - False, Pca - False, Oversampling - adasyn (24 out of 48)
# Training begins...
# Loaded ./data/X_train_adasyn.csv
# Loaded ./data/y_train_adasyn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 13:34:10
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - True, Pca - True, Oversampling - rus (25 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_rus.csv
# Loaded ./data/y_train_scaled_pca_rus.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:11
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - True, Pca - True, Oversampling - nm-3 (26 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_nm-3.csv
# Loaded ./data/y_train_scaled_pca_nm-3.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:11
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - True, Pca - True, Oversampling - cnn (27 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_cnn.csv
# Loaded ./data/y_train_scaled_pca_cnn.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:11
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - True, Pca - True, Oversampling - ros (28 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_ros.csv
# Loaded ./data/y_train_scaled_pca_ros.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:12
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - True, Pca - True, Oversampling - smote (29 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_smote.csv
# Loaded ./data/y_train_scaled_pca_smote.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:12
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - True, Pca - True, Oversampling - adasyn (30 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_pca_adasyn.csv
# Loaded ./data/y_train_scaled_pca_adasyn.csv
# Loaded ./data/X_test_scaled_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:13
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - True, Pca - False, Oversampling - rus (31 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_rus.csv
# Loaded ./data/y_train_scaled_rus.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:13
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - True, Pca - False, Oversampling - nm-3 (32 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_nm-3.csv
# Loaded ./data/y_train_scaled_nm-3.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:14
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - True, Pca - False, Oversampling - cnn (33 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_cnn.csv
# Loaded ./data/y_train_scaled_cnn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:14
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - True, Pca - False, Oversampling - ros (34 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_ros.csv
# Loaded ./data/y_train_scaled_ros.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:15
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - True, Pca - False, Oversampling - smote (35 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_smote.csv
# Loaded ./data/y_train_scaled_smote.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:15
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - True, Pca - False, Oversampling - adasyn (36 out of 48)
# Training begins...
# Loaded ./data/X_train_scaled_adasyn.csv
# Loaded ./data/y_train_scaled_adasyn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:16
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - False, Pca - True, Oversampling - rus (37 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_rus.csv
# Loaded ./data/y_train_pca_rus.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:17
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - False, Pca - True, Oversampling - nm-3 (38 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_nm-3.csv
# Loaded ./data/y_train_pca_nm-3.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:17
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - False, Pca - True, Oversampling - cnn (39 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_cnn.csv
# Loaded ./data/y_train_pca_cnn.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:17
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - False, Pca - True, Oversampling - ros (40 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_ros.csv
# Loaded ./data/y_train_pca_ros.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:18
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - False, Pca - True, Oversampling - smote (41 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_smote.csv
# Loaded ./data/y_train_pca_smote.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:18
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - False, Pca - True, Oversampling - adasyn (42 out of 48)
# Training begins...
# Loaded ./data/X_train_pca_adasyn.csv
# Loaded ./data/y_train_pca_adasyn.csv
# Loaded ./data/X_test_pca.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:19
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - False, Pca - False, Oversampling - rus (43 out of 48)
# Training begins...
# Loaded ./data/X_train_rus.csv
# Loaded ./data/y_train_rus.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:19
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - False, Pca - False, Oversampling - nm-3 (44 out of 48)
# Training begins...
# Loaded ./data/X_train_nm-3.csv
# Loaded ./data/y_train_nm-3.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:20
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - False, Pca - False, Oversampling - cnn (45 out of 48)
# Training begins...
# Loaded ./data/X_train_cnn.csv
# Loaded ./data/y_train_cnn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:20
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - False, Pca - False, Oversampling - ros (46 out of 48)
# Training begins...
# Loaded ./data/X_train_ros.csv
# Loaded ./data/y_train_ros.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:21
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - False, Pca - False, Oversampling - smote (47 out of 48)
# Training begins...
# Loaded ./data/X_train_smote.csv
# Loaded ./data/y_train_smote.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:21
#
# Starting Algorithm - ExtraTreesClassifier, Autotuning - False, Scaling - False, Pca - False, Oversampling - adasyn (48 out of 48)
# Training begins...
# Loaded ./data/X_train_adasyn.csv
# Loaded ./data/y_train_adasyn.csv
# Loaded ./data/X_test.csv
# Algorithm selected.
# Training completed.
# Done at 13:34:22

# %%
etc_results.sort_values(by="Cohen's Kappa", ascending=False)
# Out:
#               Algorithm  Non-pulsar precision  Non-pulsar recall  \
# 10  ExtraTreeClassifier              0.987080           0.990533
# 22  ExtraTreeClassifier              0.987077           0.990327
# 44  ExtraTreeClassifier              0.987474           0.989710
# 34  ExtraTreeClassifier              0.986279           0.991150
# 46  ExtraTreeClassifier              0.985682           0.991768
# 33  ExtraTreeClassifier              0.984499           0.993414
# 45  ExtraTreeClassifier              0.984499           0.993414
# 19  ExtraTreeClassifier              0.986672           0.990327
# 7   ExtraTreeClassifier              0.985081           0.991974
# 9   ExtraTreeClassifier              0.986667           0.989916
# 32  ExtraTreeClassifier              0.987264           0.989092
# 47  ExtraTreeClassifier              0.987860           0.988063
# 20  ExtraTreeClassifier              0.987858           0.987858
# 11  ExtraTreeClassifier              0.989059           0.986005
# 8   ExtraTreeClassifier              0.987454           0.988063
# 35  ExtraTreeClassifier              0.987251           0.988063
# 23  ExtraTreeClassifier              0.989461           0.985388
# 21  ExtraTreeClassifier              0.986248           0.988887
# 31  ExtraTreeClassifier              0.985620           0.987446
# 4   ExtraTreeClassifier              0.979124           0.994237
# 1   ExtraTreeClassifier              0.981451           0.990945
# 5   ExtraTreeClassifier              0.983002           0.987858
# 3   ExtraTreeClassifier              0.978710           0.993414
# 27  ExtraTreeClassifier              0.979442           0.990327
# 28  ExtraTreeClassifier              0.981372           0.986623
# 6   ExtraTreeClassifier              0.991195           0.973040
# 43  ExtraTreeClassifier              0.986517           0.978802
# 18  ExtraTreeClassifier              0.991188           0.972217
# 2   ExtraTreeClassifier              0.983278           0.980243
# 26  ExtraTreeClassifier              0.981299           0.982712
# 42  ExtraTreeClassifier              0.992807           0.965837
# 30  ExtraTreeClassifier              0.992807           0.965837
# 17  ExtraTreeClassifier              0.982547           0.973246
# 16  ExtraTreeClassifier              0.981339           0.974069
# 40  ExtraTreeClassifier              0.978579           0.977773
# 0   ExtraTreeClassifier              0.988384           0.963161
# 29  ExtraTreeClassifier              0.984120           0.969335
# 15  ExtraTreeClassifier              0.981132           0.973863
# 39  ExtraTreeClassifier              0.974328           0.984153
# 25  ExtraTreeClassifier              0.980208           0.968306
# 41  ExtraTreeClassifier              0.978781           0.968306
# 38  ExtraTreeClassifier              0.976215           0.971393
# 13  ExtraTreeClassifier              0.982737           0.960692
# 24  ExtraTreeClassifier              0.988963           0.940523
# 14  ExtraTreeClassifier              0.983326           0.946697
# 37  ExtraTreeClassifier              0.975348           0.952665
# 12  ExtraTreeClassifier              0.988496           0.919531
# 36  ExtraTreeClassifier              0.986903           0.915003
#
#     Non-pulsar F1  Pulsar precision  Pulsar recall  Pulsar F1  \
# 10       0.988803          0.906694       0.876471   0.891326
# 22       0.988699          0.904858       0.876471   0.890438
# 44       0.988591          0.899800       0.880392   0.889990
# 34       0.988709          0.911523       0.868627   0.889558
# 46       0.988716          0.916667       0.862745   0.888889
# 33       0.988937          0.931330       0.850980   0.889344
# 45       0.988937          0.931330       0.850980   0.889344
# 19       0.988496          0.904472       0.872549   0.888224
# 7        0.988515          0.918067       0.856863   0.886410
# 9        0.988288          0.900810       0.872549   0.886454
# 32       0.988177          0.894212       0.878431   0.886251
# 47       0.987962          0.886051       0.884314   0.885182
# 20       0.987858          0.884314       0.884314   0.884314
# 11       0.987530          0.870476       0.896078   0.883092
# 8        0.987758          0.885602       0.880392   0.882989
# 35       0.987657          0.885375       0.878431   0.881890
# 23       0.987420          0.866038       0.900000   0.882692
# 21       0.987566          0.891348       0.868627   0.879841
# 31       0.986532          0.878244       0.862745   0.870425
# 4        0.986623          0.935632       0.798039   0.861376
# 1        0.986175          0.904968       0.821569   0.861254
# 5        0.985424          0.878601       0.837255   0.857430
# 3        0.986008          0.926773       0.794118   0.855333
# 27       0.984855          0.896930       0.801961   0.846791
# 28       0.983990          0.865702       0.821569   0.843058
# 6        0.982033          0.781302       0.917647   0.844004
# 43       0.982645          0.812044       0.872549   0.841210
# 18       0.981610          0.776119       0.917647   0.840970
# 2        0.981758          0.817143       0.841176   0.828986
# 26       0.982005          0.833002       0.821569   0.827246
# 42       0.979136          0.741433       0.933333   0.826389
# 30       0.979136          0.741433       0.933333   0.826389
# 17       0.977874          0.766187       0.835294   0.799250
# 16       0.977691          0.769231       0.823529   0.795455
# 40       0.978176          0.789883       0.796078   0.792969
# 0        0.975610          0.717666       0.892157   0.795455
# 29       0.976672          0.744425       0.850980   0.794145
# 15       0.977484          0.767399       0.821569   0.793561
# 39       0.979216          0.832972       0.752941   0.790937
# 25       0.974221          0.729350       0.813725   0.769231
# 41       0.973515          0.725979       0.800000   0.761194
# 38       0.973798          0.739700       0.774510   0.756705
# 13       0.971589          0.691438       0.839216   0.758193
# 24       0.964135          0.613636       0.900000   0.729730
# 14       0.964664          0.625181       0.847059   0.719400
# 37       0.963873          0.630819       0.770588   0.693733
# 12       0.952767          0.539458       0.898039   0.674025
# 36       0.949594          0.521991       0.884314   0.656477
#
#     Weighted precision  Weighted recall  Weighted F1  \
# 10            0.979444         0.979698     0.979544
# 22            0.979267         0.979512     0.979366
# 44            0.979146         0.979326     0.979225
# 34            0.979178         0.979512     0.979290
# 46            0.979126         0.979512     0.979233
# 33            0.979449         0.979885     0.979476
# 45            0.979449         0.979885     0.979476
# 19            0.978864         0.979140     0.978971
# 7             0.978715         0.979140     0.978816
# 9             0.978511         0.978767     0.978615
# 32            0.978425         0.978581     0.978495
# 47            0.978189         0.978208     0.978199
# 20            0.978022         0.978022     0.978022
# 11            0.977795         0.977463     0.977609
# 8             0.977779         0.977836     0.977806
# 35            0.977574         0.977649     0.977610
# 23            0.977737         0.977277     0.977472
# 21            0.977233         0.977463     0.977333
# 31            0.975421         0.975601     0.975503
# 4             0.974993         0.975601     0.974726
# 1             0.974186         0.974856     0.974309
# 5             0.973085         0.973552     0.973266
# 3             0.973777         0.974483     0.973595
# 27            0.971604         0.972434     0.971740
# 28            0.970384         0.970944     0.970603
# 6             0.971257         0.967778     0.968922
# 43            0.969944         0.968709     0.969210
# 18            0.970758         0.967033     0.968251
# 2             0.967497         0.967033     0.967246
# 26            0.967212         0.967405     0.967305
# 42            0.968929         0.962749     0.964627
# 30            0.968929         0.962749     0.964627
# 17            0.961995         0.960142     0.960907
# 16            0.961191         0.959769     0.960380
# 40            0.960655         0.960514     0.960583
# 0             0.962669         0.956416     0.958497
# 29            0.961352         0.958093     0.959334
# 15            0.960830         0.959397     0.960013
# 39            0.960900         0.962190     0.961331
# 25            0.956379         0.953623     0.954749
# 41            0.954767         0.952319     0.953347
# 38            0.953749         0.952691     0.953177
# 13            0.955066         0.949153     0.951319
# 24            0.953311         0.936673     0.941869
# 14            0.949306         0.937232     0.941366
# 37            0.942621         0.935370     0.938212
# 12            0.945842         0.917489     0.926289
# 36            0.942741         0.912088     0.921751
#
#     Matthews corrcoefficient  Cohen's Kappa  \
# 10                     0.880          0.880
# 22                     0.879          0.879
# 44                     0.879          0.879
# 34                     0.879          0.878
# 46                     0.878          0.878
# 33                     0.879          0.878
# 45                     0.879          0.878
# 19                     0.877          0.877
# 7                      0.876          0.875
# 9                      0.875          0.875
# 32                     0.874          0.874
# 47                     0.873          0.873
# 20                     0.872          0.872
# 11                     0.871          0.871
# 8                      0.871          0.871
# 35                     0.870          0.870
# 23                     0.870          0.870
# 21                     0.867          0.867
# 31                     0.857          0.857
# 4                      0.851          0.848
# 1                      0.849          0.847
# 5                      0.843          0.843
# 3                      0.844          0.841
# 27                     0.833          0.832
# 28                     0.827          0.827
# 6                      0.829          0.826
# 43                     0.825          0.824
# 18                     0.826          0.823
# 2                      0.811          0.811
# 26                     0.809          0.809
# 42                     0.813          0.806
# 30                     0.813          0.806
# 17                     0.778          0.777
# 16                     0.774          0.773
# 40                     0.771          0.771
# 0                      0.777          0.771
# 29                     0.773          0.771
# 15                     0.772          0.771
# 39                     0.771          0.770
# 25                     0.745          0.744
# 41                     0.736          0.735
# 38                     0.731          0.731
# 13                     0.734          0.730
# 24                     0.712          0.695
# 14                     0.695          0.685
# 37                     0.662          0.658
# 12                     0.657          0.630
# 36                     0.638          0.610
#
#                                            Parameters    PCA Tuning Scaling  \
# 10  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False   True    True
# 22  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False   True   False
# 44  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False  False   False
# 34  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False  False    True
# 46  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False  False   False
# 33  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False  False    True
# 45  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False  False   False
# 19  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False   True   False
# 7   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False   True    True
# 9   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False   True    True
# 32  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False  False    True
# 47  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False  False   False
# 20  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False   True   False
# 11  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False   True    True
# 8   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False   True    True
# 35  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False  False    True
# 23  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False   True   False
# 21  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False   True   False
# 31  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False  False    True
# 4   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True   True    True
# 1   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True   True    True
# 5   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True   True    True
# 3   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True   True    True
# 27  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True  False    True
# 28  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True  False    True
# 6   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False   True    True
# 43  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False  False   False
# 18  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False   True   False
# 2   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True   True    True
# 26  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True  False    True
# 42  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False  False   False
# 30  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  False  False    True
# 17  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True   True   False
# 16  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True   True   False
# 40  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True  False   False
# 0   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True   True    True
# 29  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True  False    True
# 15  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True   True   False
# 39  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True  False   False
# 25  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True  False    True
# 41  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True  False   False
# 38  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True  False   False
# 13  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True   True   False
# 24  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True  False    True
# 14  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True   True   False
# 37  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True  False   False
# 12  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True   True   False
# 36  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...   True  False   False
#
#    Sampling
# 10    smote
# 22    smote
# 44      cnn
# 34    smote
# 46    smote
# 33      ros
# 45      ros
# 19     nm-3
# 7      nm-3
# 9       ros
# 32      cnn
# 47   adasyn
# 20      cnn
# 11   adasyn
# 8       cnn
# 35   adasyn
# 23   adasyn
# 21      ros
# 31     nm-3
# 4     smote
# 1      nm-3
# 5    adasyn
# 3       ros
# 27      ros
# 28    smote
# 6       rus
# 43     nm-3
# 18      rus
# 2       cnn
# 26      cnn
# 42      rus
# 30      rus
# 17   adasyn
# 16    smote
# 40    smote
# 0       rus
# 29   adasyn
# 15      ros
# 39      ros
# 25     nm-3
# 41   adasyn
# 38      cnn
# 13     nm-3
# 24      rus
# 14      cnn
# 37     nm-3
# 12      rus
# 36      rus
