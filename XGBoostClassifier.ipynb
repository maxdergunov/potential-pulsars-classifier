# %%
from itertools import product
from datetime import datetime

import pandas as pd

from model import choose_dataset, train_model, add_new_row, plot_conf_matrix

import warnings
warnings.filterwarnings('ignore')

# %%
tune_list = [True, False]
scaling_list = [True]
pca_list = [False]
sampling_list = ['rus', 'nm-3', 'cnn', 'ros', 'smote', 'adasyn']

xgbc_results = pd.DataFrame(columns=['Algorithm', 'Non-pulsar precision', 'Non-pulsar recall', 'Non-pulsar F1', 'Pulsar precision', 'Pulsar recall', 'Pulsar F1', 'Weighted precision', 'Weighted recall', 'Weighted F1', 'Matthews corrcoefficient', "Cohen's Kappa", 'Parameters', 'PCA', 'Tuning', 'Scaling', 'Sampling'])

n = 0

print('Start time at', datetime.now().strftime("%H:%M:%S"))

for tuning, scaling, pca, sampling in product(tune_list, scaling_list, pca_list, sampling_list):
    n += 1
    print('Starting Algorithm - Gradient Boosting, Autotuning - {}, Scaling - {}, Pca - {}, Oversampling - {} ({} out of {})'.format(
        tuning, scaling, pca, sampling, n, len(list(product(tune_list, scaling_list, pca_list, sampling_list)))))
    

    algorithm, preds, y_test = train_model(algo='xgbc', pca=pca, tuning=tuning, scaling=scaling, sampling=sampling, n_splits=3, n_jobs=7, scoring='cohen', verbose=0)     
    row = add_new_row(algorithm, preds, y_test)
    row['Algorithm'] = 'Gradient Boosting'
    row['PCA'] = pca
    row['Tuning'] = tuning
    row['Scaling'] = scaling
    row['Sampling'] = sampling
    xgbc_results.loc[len(xgbc_results)] = row
    print('Done at', datetime.now().strftime("%H:%M:%S"), '\n')
    xgbc_results.to_csv('./results/xgbc_results.csv', index=False)
# Out:
# Start time at 14:43:32
# Starting Algorithm - Gradient Boosting, Autotuning - True, Scaling - True, Pca - False, Oversampling - rus (1 out of 12)
# Training begins...
# Loaded ./data/X_train_scaled_rus.csv
# Loaded ./data/y_train_scaled_rus.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 14:49:28
#
# Starting Algorithm - Gradient Boosting, Autotuning - True, Scaling - True, Pca - False, Oversampling - nm-3 (2 out of 12)
# Training begins...
# Loaded ./data/X_train_scaled_nm-3.csv
# Loaded ./data/y_train_scaled_nm-3.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 14:53:58
#
# Starting Algorithm - Gradient Boosting, Autotuning - True, Scaling - True, Pca - False, Oversampling - cnn (3 out of 12)
# Training begins...
# Loaded ./data/X_train_scaled_cnn.csv
# Loaded ./data/y_train_scaled_cnn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 14:59:15
#
# Starting Algorithm - Gradient Boosting, Autotuning - True, Scaling - True, Pca - False, Oversampling - ros (4 out of 12)
# Training begins...
# Loaded ./data/X_train_scaled_ros.csv
# Loaded ./data/y_train_scaled_ros.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 15:37:17
#
# Starting Algorithm - Gradient Boosting, Autotuning - True, Scaling - True, Pca - False, Oversampling - smote (5 out of 12)
# Training begins...
# Loaded ./data/X_train_scaled_smote.csv
# Loaded ./data/y_train_scaled_smote.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 16:15:13
#
# Starting Algorithm - Gradient Boosting, Autotuning - True, Scaling - True, Pca - False, Oversampling - adasyn (6 out of 12)
# Training begins...
# Loaded ./data/X_train_scaled_adasyn.csv
# Loaded ./data/y_train_scaled_adasyn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Tuning begins...
# Tuning completed.
# Training completed.
# Done at 16:52:47
#
# Starting Algorithm - Gradient Boosting, Autotuning - False, Scaling - True, Pca - False, Oversampling - rus (7 out of 12)
# Training begins...
# Loaded ./data/X_train_scaled_rus.csv
# Loaded ./data/y_train_scaled_rus.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 16:52:48
#
# Starting Algorithm - Gradient Boosting, Autotuning - False, Scaling - True, Pca - False, Oversampling - nm-3 (8 out of 12)
# Training begins...
# Loaded ./data/X_train_scaled_nm-3.csv
# Loaded ./data/y_train_scaled_nm-3.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 16:52:48
#
# Starting Algorithm - Gradient Boosting, Autotuning - False, Scaling - True, Pca - False, Oversampling - cnn (9 out of 12)
# Training begins...
# Loaded ./data/X_train_scaled_cnn.csv
# Loaded ./data/y_train_scaled_cnn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 16:52:48
#
# Starting Algorithm - Gradient Boosting, Autotuning - False, Scaling - True, Pca - False, Oversampling - ros (10 out of 12)
# Training begins...
# Loaded ./data/X_train_scaled_ros.csv
# Loaded ./data/y_train_scaled_ros.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 16:52:49
#
# Starting Algorithm - Gradient Boosting, Autotuning - False, Scaling - True, Pca - False, Oversampling - smote (11 out of 12)
# Training begins...
# Loaded ./data/X_train_scaled_smote.csv
# Loaded ./data/y_train_scaled_smote.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 16:52:50
#
# Starting Algorithm - Gradient Boosting, Autotuning - False, Scaling - True, Pca - False, Oversampling - adasyn (12 out of 12)
# Training begins...
# Loaded ./data/X_train_scaled_adasyn.csv
# Loaded ./data/y_train_scaled_adasyn.csv
# Loaded ./data/X_test_scaled.csv
# Algorithm selected.
# Training completed.
# Done at 16:52:50

# %%
xgbc_results.sort_values(by="Cohen's Kappa", ascending=False)
# Out:
#             Algorithm  Non-pulsar precision  Non-pulsar recall  Non-pulsar F1  \
# 4   Gradient Boosting              0.987692           0.990945       0.989316
# 3   Gradient Boosting              0.985665           0.990533       0.988093
# 5   Gradient Boosting              0.989866           0.984976       0.987415
# 2   Gradient Boosting              0.987649           0.987446       0.987548
# 10  Gradient Boosting              0.985653           0.989710       0.987677
# 9   Gradient Boosting              0.984659           0.990739       0.987690
# 1   Gradient Boosting              0.985835           0.988269       0.987050
# 11  Gradient Boosting              0.988831           0.983947       0.986383
# 8   Gradient Boosting              0.986186           0.984359       0.985271
# 0   Gradient Boosting              0.992772           0.961103       0.976681
# 6   Gradient Boosting              0.992752           0.958428       0.975288
# 7   Gradient Boosting              0.984247           0.938671       0.960919
#
#     Pulsar precision  Pulsar recall  Pulsar F1  Weighted precision  \
# 4           0.910931       0.882353   0.896414            0.980401
# 3           0.905350       0.862745   0.883534            0.978035
# 5           0.863296       0.903922   0.883142            0.977843
# 2           0.880626       0.882353   0.881489            0.977483
# 10          0.897959       0.862745   0.880000            0.977323
# 9           0.906250       0.852941   0.878788            0.977211
# 1           0.885542       0.864706   0.875000            0.976308
# 11          0.853933       0.894118   0.873563            0.976017
# 8           0.853565       0.868627   0.861030            0.973588
# 0           0.715789       0.933333   0.810213            0.966462
# 6           0.702065       0.933333   0.801347            0.965140
# 7           0.594558       0.856863   0.702008            0.947230
#
#     Weighted recall  Weighted F1  Matthews corrcoefficient  Cohen's Kappa  \
# 4          0.980630     0.980491                     0.886          0.886
# 3          0.978394     0.978161                     0.872          0.872
# 5          0.977277     0.977510                     0.871          0.871
# 2          0.977463     0.977473                     0.869          0.869
# 10         0.977649     0.977449                     0.868          0.868
# 9          0.977649     0.977345                     0.867          0.866
# 1          0.976532     0.976407                     0.862          0.862
# 11         0.975414     0.975667                     0.860          0.860
# 8          0.973366     0.973470                     0.846          0.846
# 0          0.958465     0.960868                     0.796          0.787
# 6          0.956044     0.958765                     0.787          0.777
# 7          0.930900     0.936325                     0.679          0.664
#
#                                            Parameters    PCA Tuning Scaling  \
# 4   {'objective': 'binary:logistic', 'base_score':...  False   True    True
# 3   {'objective': 'binary:logistic', 'base_score':...  False   True    True
# 5   {'objective': 'binary:logistic', 'base_score':...  False   True    True
# 2   {'objective': 'binary:logistic', 'base_score':...  False   True    True
# 10  {'objective': 'binary:logistic', 'base_score':...  False  False    True
# 9   {'objective': 'binary:logistic', 'base_score':...  False  False    True
# 1   {'objective': 'binary:logistic', 'base_score':...  False   True    True
# 11  {'objective': 'binary:logistic', 'base_score':...  False  False    True
# 8   {'objective': 'binary:logistic', 'base_score':...  False  False    True
# 0   {'objective': 'binary:logistic', 'base_score':...  False   True    True
# 6   {'objective': 'binary:logistic', 'base_score':...  False  False    True
# 7   {'objective': 'binary:logistic', 'base_score':...  False  False    True
#
#    Sampling
# 4     smote
# 3       ros
# 5    adasyn
# 2       cnn
# 10    smote
# 9       ros
# 1      nm-3
# 11   adasyn
# 8       cnn
# 0       rus
# 6       rus
# 7      nm-3
